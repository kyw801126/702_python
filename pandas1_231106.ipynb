# %%
import pandas as pd

# %%
dict_data = {'a':1, 'b':2, 'c':3}

# %%
# 판다스 Series()함수로 딕셔너리를 시리즈로 변환
sr = pd.Series(dict_data)
print(sr)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(type(sr))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 리스트를 시리즈로 변환하여 변수에 저장
list_data = ['2019-01-01', 3.14, 'ABCF', 100, True]
sr = pd.Series(list_data)
print(sr)
print(type(sr))
# Out:
# 0    2019-01-01
# 1          3.14
# 2          ABCF
# 3           100
# 4          True
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
# 인덱스 배열은 변수 idx 에 저장, 데이터 값은 val 변수에 저장
idx = sr.index
val = sr.values
print(idx)
print('\n')
print(val)
# Out:
# RangeIndex(start=0, stop=5, step=1)
#
#
# ['2019-01-01' 3.14 'ABCF' 100 True]

# %%
# 튜플을 시리즈로 변환
tup_data = ('영인', '2010-05-01', "여", True)
sr = pd.Series(tup_data, index=["이름", "생년월일", "성별", "학생여부"])
print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
# 원소를 1개 선택
print(sr[0])
# Out:
# 영인

# %%
# '이름' 라벨을 가진 원소를 선택
print(sr['이름'])
# Out:
# 영인

# %%
# 여러개 원소 선택
print(sr[[1, 2]])
print(sr[['생년월일', '성별']])

# %%
print(sr[1:3])
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
print(sr['생년월일':'성별'])
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %% [markdown]
# 시리즈 만들기 실습

# %%
pop = [9904312, 3443284, 2893878, 2466032] # 인구 : 서울, 부산, 인천, 대구

# %%
metro = pd.Series(pop, index=[ '서울', '부산', '인천', '대구'])
metro
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# dtype: int64

# %%
#서울 부산가져오기
# metro[[0,1]]
metro[['서울','부산']]
# Out:
# 서울    9904312
# 부산    3443284
# dtype: int64

# %%
metro / 1000000
# Out:
# 서울    9.904312
# 부산    3.443284
# 인천    2.893878
# 대구    2.466032
# dtype: float64

# %%
import numpy as np
dice = pd.Series(np.random.randint(1, 7, 10))
dice * 10
# Out:
# 0    40
# 1    20
# 2    60
# 3    20
# 4    10
# 5    40
# 6    40
# 7    30
# 8    30
# 9    10
# dtype: int64

# %%
# 시리즈와 딕셔너리
metro
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# dtype: int64

# %%
for key, value in metro.items():
  print(key, value)
# Out:
# 서울 9904312
# 부산 3443284
# 인천 2893878
# 대구 2466032

# %%
a = {'서울':904312,'부산': 443284, '인천': 893878, '대전': 245852}
metro2 = pd.Series(a)

# %%
metro - metro2
# Out:
# 대구          NaN
# 대전          NaN
# 부산    3000000.0
# 서울    9000000.0
# 인천    2000000.0
# dtype: float64

# %%
# 속성
print(metro.index)
print(metro.values)
# Out:
# Index(['서울', '부산', '인천', '대구'], dtype='object')
# [9904312 3443284 2893878 2466032]

# %%
metro.name = "광역시"

# %%
metro
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# Name: 광역시, dtype: int64

# %% [markdown]
# method

# %%
# count, unique, nunique, value_counts
dice

# %%
#원소의 갯수
dice.count()
# Out:
# 10

# %%
# unique는 고유한 원소
dice.unique()
# Out:
# array([4, 2, 6, 1, 3])

# %%
# unique의 갯수
dice.nunique()
# Out:
# 5

# %%
# value_counts 벨류의 갯수
dice.value_counts()
# Out:
# 4    3
# 2    2
# 1    2
# 3    2
# 6    1
# dtype: int64

# %%
# sum, mean, min, max
dice.sum(), dice.mean(), dice.min(), dice.max()
# Out:
# (30, 3.0, 1, 6)

# %%
metro.sum(), metro.mean(), metro.min(), metro.max()
# Out:
# (18707506, 4676876.5, 2466032, 9904312)

# %%
# 요약 통계
metro.describe()
# Out:
# count    4.000000e+00
# mean     4.676876e+06
# std      3.507836e+06
# min      2.466032e+06
# 25%      2.786916e+06
# 50%      3.168581e+06
# 75%      5.058541e+06
# max      9.904312e+06
# Name: 광역시, dtype: float64

# %%
metro
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# Name: 광역시, dtype: int64

# %%
# sort 오름차순
metro.sort_values()
# Out:
# 대구    2466032
# 인천    2893878
# 부산    3443284
# 서울    9904312
# Name: 광역시, dtype: int64

# %%
# sort 내림차순
metro.sort_values(ascending=False)
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# Name: 광역시, dtype: int64

# %%
metro.sort_values()[::-1]
# Out:
# 서울    9904312
# 부산    3443284
# 인천    2893878
# 대구    2466032
# Name: 광역시, dtype: int64

# %%
metro.sort_index()
# Out:
# 대구    2466032
# 부산    3443284
# 서울    9904312
# 인천    2893878
# Name: 광역시, dtype: int64

# %% [markdown]
# DataFrame

# %%
# 열이름을  key로 하고, 리스트를 value로 갖는 딕셔너리
dic_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9],
            'c3': [10,11,12], 'c4':[13, 14, 15]}

# %%
df = pd.DataFrame(dic_data)

# %%
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    c0  c1  c2  c3  c4
# 0   1   4   7  10  13
# 1   2   5   8  11  14
# 2   3   6   9  12  15

# %%
# 행 인덱스/열 이름을 지정하여, 데이터프레임 만들기
df1 = pd.DataFrame([[15, '남', '덕영중'], [17, '여', '수리중']],
                   index = ['준서', '예은'],
                   columns = ['나이', '성별', '학교'])

# %%
df1
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
# 열이름 바꾸기 df1.rename(딕셔너리)
df1.rename(columns={'나이':'연령', '성별':'남여', '학교':'소속'}, inplace=True)

# %%
print(df1)
# Out:
#     연령 남여   소속
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
# 행이름 바꾸기 df1.rename(딕셔너리)
df1.rename(index={"준서":"학생1", "예은":"학생2"}, inplace=True)
df1 = df1.rename(index={"준서":"학생1", "예은":"학생2"})

# %%
df1
# Out:
#      연령 남여   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# 데이터프레임 지우기
# df에 학생 성적을 저장
exam_data = {'수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data, index=['서준', '우현', '인아'])
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 데이터 프레임 df 를 복제하여 df2에 저장하고 df2의 1개 행삭제
df2 = df[:]

# %%
df2.drop('우현', inplace=True)
df2

# %%
df3 = df
df3.drop(['우현', '인아'], inplace=True, axis=0)

# %%
df3
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
df
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
# 열삭제
exam_data = {'수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data, index=['서준', '우현', '인아'])
df

# %%
df4 = df.copy()
df4.drop('수학', inplace=True, axis=1)
df4
# Out:
#     영어   음악   체육
# 서준  98   85  100
# 우현  89   95   90
# 인아  95  100   90

# %%
df5 = df.copy()
df5.drop(['영어', '음악'], inplace=True, axis=1)
df5
# Out:
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %%
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 선택 행인덱스를 사용해서 행 1개를 선택
label1 = df.loc['서준'] #location
position1 = df.iloc[0]#intiger location

# %%
print(label1)
print(position1)

# %%
# 행 인덱스를 사용해서 2개 이상 행 선택
# loc 서준 우현 가져오기 , iloc를 사용 서준 우현
label2 = df.loc[['서준', '우현']] #location
position2 = df.iloc[[0,1]]#intiger location

# %%
print(label2)
print(position2)

# %%
label3 = df.loc['서준':'우현'] #location
position3 = df.iloc[0:2]#intiger location

# %%
print(label3)
print(position3)
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90

# %%
# 열선택
exam_data = {'이름': ['서준', '우현', '인아'],
             '수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data)
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
# 수학 점수 데이터만 선택 해서 math1에 저장
math1 = df['수학']
print(math1)
print(type(math1))

# %%
# 영어 점수 데이만 선택해서 english에 저장
english = df.영어
print(english)
print(type(english))

# %%
# '음악', '체육' music_gym 저장
music_gym = df[['음악', '체육']]
print(music_gym)
print(type(music_gym))

# %%
# 수학 점수 데이터만 선택 해서 math1에 저장
math2 = df[['수학']]
print(math2)
print(type(math2))

# %%
math2 = pd.DataFrame(df['수학'])
math2

# %%
# '이름' 열을 새로운 인덱스로 지정함
df.set_index('이름', inplace=True)
df

# %%
# 데이터 프레임 df에서 특정 원소 1개 선택
# 서준의 음악점수
a = df.loc['서준', '음악']
print(a)
# Out:
# 85

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
b = df.iloc[0, 2]
print(b)
# Out:
# 85

# %%
# 데이터프레임df의 특정원소 2개 이상 선택
# 서준이의 음악 체육점수
c = df.iloc[0, 2:] # df.iloc[0, [2, 3]]
print(c)
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 서준 우현의 음악 체육
# 따로
h = df.loc[['서준', '우현'],['음악', '체육']]
h = df.iloc[[0, 1],[2, 3]]
# 슬라이싱
i = df.loc['서준':'우현', '음악':'체육']
i = df.iloc[0:2, 2:]

# %%
# 추가하기
# 데이터프레임의 국어 점수열을 추가 점수는 80점으로 통일
df['국어'] = 80
df

# %%
# 데이터프레임의 새로운 행추가 '동규' 5과목 점수
df.loc['동규'] = [90, 80,70, 60, 80]

# %%
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  80
# 우현  80  89   95   90  80
# 인아  70  95  100   90  80
# 동규  90  80   70   60  80

# %%
exam_data = {'이름': ['서준', '우현', '인아'],
             '수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data)

# %%
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
# 행 3에 0을 모두 입력하고
df.loc[3] = 0

# %%
#행 4에 동규를 추가
df.loc[4] = ['동규', 90, 80, 70, 60]

# %%
# 새로운 행 '행5'를 추가하는데 행 3을 복사
df.loc['행5'] = df.loc[3]
df
# Out:
#     이름  수학  영어   음악   체육
# 0   서준  90  98   85  100
# 1   우현  80  89   95   90
# 2   인아  70  95  100   90
# 3    0   0   0    0    0
# 4   동규  90  80   70   60
# 행5   0   0   0    0    0

# %%
exam_data = {'이름': ['서준', '우현', '인아'],
             '수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data)

# %%
df.set_index('이름', inplace=True)

# %%
# 데이터프레임 df의 특정 원소를 변경하는 방법
# 서준 체육 점수 80점으로 바꾸기
df.loc['서준', '체육'] = 80 # df.loc['서준']['체육']
df

# %%
df.iloc[0, 3] = 70 # df.iloc[0][3] = 70
df

# %%
# 데이터프레임 df의 원소 여러개를 변경하는 법
# 서준의 음악, 체육점수를 50점으로 바꾸기
df.loc['서준', ['음악', '체육']] = 50
df

# %%
# 서준의 음악은 100점 체육은 50점으로 변경
df.loc['서준', ['음악', '체육']] = [100, 50]
# df.loc['서준', ['음악', '체육']] = 100, 50
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98  100  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
# 전치 transpose
df = df.T

# %%
df = df.transpose()
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98  100  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
exam_data = {'이름': ['서준', '우현', '인아'],
             '수학' : [90, 80, 70], '영어':[98, 89, 95],
             '음악':[85, 95, 100], '체육': [100, 90, 90]}
df = pd.DataFrame(exam_data)

# %%
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
# 특정열을 데이터프레임의 행인덱스로 지정
n_df = df.set_index(['이름'])
n_df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
n_df2 = n_df.set_index('음악')
n_df2
# Out:
#      수학  영어   체육
# 음악
# 85   90  98  100
# 95   80  89   90
# 100  70  95   90

# %%
n_df3 = n_df.set_index(['수학', '음악'])
n_df3
# Out:
#         영어   체육
# 수학 음악
# 90 85   98  100
# 80 95   89   90
# 70 100  95   90

# %%
# 인덱스를 변경하는 reindex
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9],
            'c3': [10,11,12], 'c4':[13, 14, 15]}

# %%
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
new_index = ['r0', 'r1', 'r2', 'r3', 'r4']
ndf = df.reindex(new_index)
ndf
# Out:
#      c0   c1   c2    c3    c4
# r0  1.0  4.0  7.0  10.0  13.0
# r1  2.0  5.0  8.0  11.0  14.0
# r2  3.0  6.0  9.0  12.0  15.0
# r3  NaN  NaN  NaN   NaN   NaN
# r4  NaN  NaN  NaN   NaN   NaN

# %%
# reindex를 통해서 발생한 새index에 숫자 0으로 채우기
new_index = ['r0', 'r1', 'r2', 'r3', 'r4']
ndf2 = df.reindex(new_index, fill_value=0)
ndf2
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
# reset_index 인덱스를 초기화
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9],
            'c3': [10,11,12], 'c4':[13, 14, 15]}

# %%
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
n_df = df.reset_index()
print(n_df)
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
# reset_index 인덱스를 초기화
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9],
            'c3': [10,11,12], 'c4':[13, 14, 15]}
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 데이터프레임의 인덱스를 내림차순으로 정렬
n_df = df.sort_index(ascending=False)
n_df
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
# sort_value로 데이를 기준으로 정렬 : c1을 기존으로
ndf4 = df.sort_values(by='c1', ascending=False)
ndf4
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
# 시리즈 연산
# 딕셔너리로 시리즈 만들기
student1 = pd.Series({'국어':100, '영어':80, '수학':90})
student1
# Out:
# 국어    100
# 영어     80
# 수학     90
# dtype: int64

# %%
# 학생의 각 과목별 점수를 200으로 나누기
percentage = student1 / 200
percentage
# Out:
# 국어    0.50
# 영어    0.40
# 수학    0.45
# dtype: float64

# %%
student1 = pd.Series({'국어':100, '영어':80, '수학':90})
student2 = pd.Series({'수학':80, '국어':90, '영어':80})

# %%
# 두학생의 과목별 점수 사칙연산
add = student1 + student2
sub = student1 - student2
mul = student1 * student2
div = student1 / student2
print(add)
print(sub)
print(mul)
print(div)
# Out:
# 국어    190
# 수학    170
# 영어    160
# dtype: int64

# %%
# 사칙 연산 결과를 데이터 프레임으로 합치기 (시리즈 -> 데이터프레임)
result = pd.DataFrame([add, sub, mul, div],
                      index=['덧셈', '뺄셈', '곱셈', '나눗셈'])
result
# Out:
#               국어        수학      영어
# 덧셈    190.000000   170.000   160.0
# 뺄셈     10.000000    10.000     0.0
# 곱셈   9000.000000  7200.000  6400.0
# 나눗셈     1.111111     1.125     1.0

# %%
student1 = pd.Series({'국어':np.nan, '영어':80, '수학':90})
student2 = pd.Series({'수학':80, '국어':90, '영어':80})

# %%
add = student1 + student2
sub = student1 - student2
mul = student1 * student2
div = student1 / student2
print(add)
print(sub)
print(mul)
print(div)
# Out:
# 국어      NaN
# 수학    170.0
# 영어    160.0
# dtype: float64
# 국어     NaN
# 수학    10.0
# 영어     0.0
# dtype: float64
# 국어       NaN
# 수학    7200.0
# 영어    6400.0
# dtype: float64
# 국어      NaN
# 수학    1.125
# 영어    1.000
# dtype: float64

# %%
# 두 학생의 과목별 점수로 사칙연산 수행( 연산메소드 사용)
sr_add = student1.add(student2, fill_value=0)
sr_sub = student1.sub(student2, fill_value=0)
sr_mul = student1.mul(student2, fill_value=0)
sr_div = student1.div(student2, fill_value=0)

# %%
result = pd.DataFrame([sr_add, sr_sub, sr_mul, sr_div],
                      index=['덧셈', '뺄셈', '곱셈', '나눗셈'])
result
# Out:
#        국어        수학      영어
# 덧셈   90.0   170.000   160.0
# 뺄셈  -90.0    10.000     0.0
# 곱셈    0.0  7200.000  6400.0
# 나눗셈   0.0     1.125     1.0

# %% [markdown]
# titanic

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
df = titanic.loc[:, ['age', 'fare']]
# titanic[['age', 'fare']]

# %%
df.head() # 기본값 5개 출력
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df.tail()
# Out:
#       age   fare
# 886  27.0  13.00
# 887  19.0  30.00
# 888   NaN  23.45
# 889  26.0  30.00
# 890  32.0   7.75

# %%
# 데이터프레임에 숫자 10 더하기
addtion = df + 10

# %%
addtion.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
addtion.tail()
# Out:
#       age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888   NaN  33.45
# 889  36.0  40.00
# 890  42.0  17.75

# %%
print(type(addtion))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
len(sns.get_dataset_names())
# Out:
# 22
