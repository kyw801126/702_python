# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('./data/유투브랭킹231213.csv')
df.head()

# %%
plt.figure(figsize=(12,8))
plt.barh(df.채널명.head(20), df.구독자수.head(20))
plt.title('구독자수 Top20')
plt.show()

# %%
# plt.figure(figsize=(12, 8))
sns.barplot(y='채널명', x='구독자수', data=df.head(20))
plt.title('구독자수 탑20')
plt.show()

# %% [markdown]
# ### 조회수top20채널

# %%
df_view = df.sort_values(by='조회수', ascending=False)
df_view

# %%
sns.barplot(y='채널명', x = '조회수', data=df_view.head(20))
plt.title('조회수 탑20')
plt.show()

# %% [markdown]
# ### 비디오수 많은 채널 탑 20개

# %%
df_video = df.sort_values(by='비디오수', ascending=False)
sns.barplot(y='채널명', x = '비디오수', data=df_video.head(20))
plt.title('비디오수 탑20')
plt.show()

# %% [markdown]
# ### 카테고리별 채널수

# %%
df_cat = df.카테고리.value_counts().to_frame()
df_cat.head(10)
# Out:
#            count
# 카테고리
# 미분류          202
# 음악/댄스/가수     149
# 키즈/어린이       130
# TV/방송        113
# 음식/요리/레시피     70
# BJ/인물/연예인     59
# 뉴스/정치/사회      58
# 게임            49
# 취미/라이프        29
# 영화/만화/애니      29

# %%
sns.barplot(data=df_cat.head(10), y=df_cat.index[:10], x='count')
plt.title('카테고리별 채널수')
plt.show()

# %% [markdown]
# ### 카테고리별 구독자수 합 평균 집계

# %%
df.groupby('카테고리')[['구독자수']].mean().head()

# %%
df_sub_mean = df.pivot_table('구독자수', '카테고리').sort_values('구독자수', ascending=False)
df_sub_mean

# %%
sns.barplot(data=df_sub_mean.head(10), y=df_sub_mean.index[:10], x='구독자수')
plt.title('카테고리별 구독자 평균수')
plt.show()
